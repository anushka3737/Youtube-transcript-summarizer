# %%
pip install youtube_transcript_api
# Out:
# Requirement already satisfied: youtube_transcript_api in c:\users\lenovo\anaconda3\lib\site-packages (0.4.4)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from youtube_transcript_api) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -q transformers

# %%
# !pip install -q youtube_transcript_api

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
link = 'https://www.youtube.com/watch?v=cEUJ0EO-ncA'

# %%
video_id = link.split('=')[1]

# %%
YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'text': '[Applause]', 'start': 9.76, 'duration': 5.999},
#  {'text': '14 growing industries of the future',
#   'start': 12.799,
#   'duration': 4.801},
#  {'text': 'in the past few years the leaps being',
#   'start': 15.759,
#   'duration': 4.001},
#  {'text': 'made in our entire global economic',
#   'start': 17.6,
#   'duration': 2.72},
#  {'text': 'system', 'start': 19.76, 'duration': 3.519},
#  {'text': 'are quicker and larger than ever not',
#   'start': 20.32,
#   'duration': 4.32},
#  {'text': 'many economists or', 'start': 23.279, 'duration': 3.361},
#  {'text': 'tech experts can answer with confidence',
#   'start': 24.64,
#   'duration': 3.6},
#  {'text': 'how they envision the economy', 'start': 26.64, 'duration': 5.2},
#  {'text': '20 years from today', 'start': 28.24, 'duration': 5.999},
#  {'text': 'as new technologies are prevailing new',
#   'start': 31.84,
#   'duration': 4.08},
#  {'text': 'horizons are being tapped', 'start': 34.239, 'duration': 3.84},
#  {'text': 'and new industries are being shaped that',
#   'start': 35.92,
#   'duration': 3.6},
#  {'text': 'we never thought of', 'start': 38.079, 'duration': 3.761},
#  {'text': 'until recently being able to forecast',
#   'start': 39.52,
#   'duration': 4.08},
#  {'text': 'these changes will be the most critical',
#   'start': 41.84,
#   'duration': 2.16},
#  {'text': 'factor', 'start': 43.6, 'duration': 2.32},
#  {'text': 'in your decision to pursue a certain',
#   'start': 44.0,
#   'duration': 3.039},
#  {'text': 'career or', 'start': 45.92, 'duration': 3.52},
#  {'text': 'invest in one industry or the other',
#   'start': 47.039,
#   'duration': 4.0},
#  {'text': "that's why we thought we should imagine",
#   'start': 49.44,
#   'duration': 4.0},
#  {'text': 'together which way the ship is sailing',
#   'start': 51.039,
#   'duration': 5.801},
#  {'text': 'so here are 14 growing industries of the',
#   'start': 53.44,
#   'duration': 6.4},
#  {'text': 'future', 'start': 56.84, 'duration': 3.0},
#  {'text': 'number one internet of things in the',
#   'start': 70.32,
#   'duration': 4.88},
#  {'text': 'past the internet was the thing that',
#   'start': 73.119,
#   'duration': 4.0},
#  {'text': 'most of us used only when we were on our',
#   'start': 75.2,
#   'duration': 4.4},
#  {'text': 'computers then some years ago it began',
#   'start': 77.119,
#   'duration': 4.081},
#  {'text': 'making it to our mobile phones', 'start': 79.6, 'duration': 4.0},
#  {'text': 'then our video game consoles and today',
#   'start': 81.2,
#   'duration': 4.16},
#  {'text': "we're heading in a path where we won't",
#   'start': 83.6,
#   'duration': 2.64},
#  {'text': 'need to say', 'start': 85.36, 'duration': 3.84},
#  {'text': "i'm on the internet any longer i did not",
#   'start': 86.24,
#   'duration': 4.64},
#  {'text': 'see that coming', 'start': 89.2, 'duration': 4.0},
#  {'text': 'almost everything we use both indoors',
#   'start': 90.88,
#   'duration': 4.0},
#  {'text': 'and outdoors will be on the internet',
#   'start': 93.2,
#   'duration': 3.52},
#  {'text': 'from our fridges and washing machines to',
#   'start': 94.88,
#   'duration': 3.44},
#  {'text': 'our power supply and home security',
#   'start': 96.72,
#   'duration': 2.399},
#  {'text': 'systems', 'start': 98.32, 'duration': 2.72},
#  {'text': "that's why knowledge of networks data",
#   'start': 99.119,
#   'duration': 4.0},
#  {'text': 'communication and software will be',
#   'start': 101.04,
#   'duration': 3.759},
#  {'text': 'skills that are needed in pretty much',
#   'start': 103.119,
#   'duration': 3.601},
#  {'text': 'every single industry out there',
#   'start': 104.799,
#   'duration': 4.081},
#  {'text': 'manufacturing construction and service',
#   'start': 106.72,
#   'duration': 4.079},
#  {'text': 'industries will be on a constant search',
#   'start': 108.88,
#   'duration': 2.72},
#  {'text': 'for new', 'start': 110.799, 'duration': 2.721},
#  {'text': 'internet-based mechanisms to incorporate',
#   'start': 111.6,
#   'duration': 3.6},
#  {'text': 'into their product in order to gain an',
#   'start': 113.52,
#   'duration': 3.199},
#  {'text': 'edge in the market', 'start': 115.2, 'duration': 3.12},
#  {'text': 'the tech geeks will become the ones',
#   'start': 116.719,
#   'duration': 3.921},
#  {'text': 'helping operate our entire environment',
#   'start': 118.32,
#   'duration': 3.839},
#  {'text': 'the internet of things will actually',
#   'start': 120.64,
#   'duration': 3.92},
#  {'text': 'include almost all of the things',
#   'start': 122.159,
#   'duration': 5.761},
#  {'text': 'internet so helpful number two', 'start': 124.56, 'duration': 5.28},
#  {'text': 'artificial intelligence', 'start': 127.92, 'duration': 4.08},
#  {'text': 'google studies our behavior facebook',
#   'start': 129.84,
#   'duration': 3.44},
#  {'text': 'learns our preferences', 'start': 132.0, 'duration': 3.44},
#  {'text': 'we ask siri to find us near places to',
#   'start': 133.28,
#   'duration': 3.2},
#  {'text': 'eat and', 'start': 135.44, 'duration': 3.12},
#  {'text': 'we let amazon guide us through the vast',
#   'start': 136.48,
#   'duration': 4.08},
#  {'text': 'aisles of the digital market', 'start': 138.56, 'duration': 3.92},
#  {'text': 'ever since the machines began acquiring',
#   'start': 140.56,
#   'duration': 3.12},
#  {'text': 'knowledge of their own', 'start': 142.48, 'duration': 2.96},
#  {'text': 'they have taken huge leaps towards',
#   'start': 143.68,
#   'duration': 3.76},
#  {'text': 'developing a real humanly', 'start': 145.44, 'duration': 4.24},
#  {'text': "consciousness today we're on the verge",
#   'start': 147.44,
#   'duration': 4.159},
#  {'text': 'of an era where we will move around in',
#   'start': 149.68,
#   'duration': 3.279},
#  {'text': 'self-driving cars', 'start': 151.599, 'duration': 4.481},
#  {'text': 'work alongside robots and read books or',
#   'start': 152.959,
#   'duration': 5.041},
#  {'text': 'listen to music that was created by a',
#   'start': 156.08,
#   'duration': 4.56},
#  {'text': 'machine some of us are actually doing',
#   'start': 158.0,
#   'duration': 3.519},
#  {'text': 'some of these things', 'start': 160.64, 'duration': 3.44},
#  {'text': 'already alexa can you pour me a cup of',
#   'start': 161.519,
#   'duration': 3.041},
#  {'text': 'water', 'start': 164.08, 'duration': 3.68},
#  {'text': 'watch watch watch what', 'start': 164.56, 'duration': 3.2},
#  {'text': 'the field of artificial intelligence in',
#   'start': 169.68,
#   'duration': 3.76},
#  {'text': 'the coming decades will become',
#   'start': 171.519,
#   'duration': 4.961},
#  {'text': 'one of the most vibrant arenas',
#   'start': 173.44,
#   'duration': 6.159},
#  {'text': 'for endless experimentation also',
#   'start': 176.48,
#   'duration': 4.88},
#  {'text': 'as everything becomes connected thanks',
#   'start': 179.599,
#   'duration': 3.201},
#  {'text': 'to the internet of things', 'start': 181.36, 'duration': 3.519},
#  {'text': 'more and more data related our behavior',
#   'start': 182.8,
#   'duration': 3.04},
#  {'text': 'will be collected', 'start': 184.879, 'duration': 2.72},
#  {'text': 'and the machines will have infinitely',
#   'start': 185.84,
#   'duration': 3.92},
#  {'text': 'more material to learn from', 'start': 187.599, 'duration': 3.681},
#  {'text': "don't forget that artificial", 'start': 189.76, 'duration': 3.52},
#  {'text': 'intelligence is not only a field',
#   'start': 191.28,
#   'duration': 3.92},
#  {'text': 'that is exclusive to the computer',
#   'start': 193.28,
#   'duration': 3.039},
#  {'text': 'scientists', 'start': 195.2, 'duration': 3.28},
#  {'text': "we're talking about creating brains like",
#   'start': 196.319,
#   'duration': 3.2},
#  {'text': 'ours and', 'start': 198.48, 'duration': 3.2},
#  {'text': 'potentially ones that will even be way',
#   'start': 199.519,
#   'duration': 3.601},
#  {'text': 'more powerful than ours', 'start': 201.68, 'duration': 4.479},
#  {'text': 'they will live with talk to and affect',
#   'start': 203.12,
#   'duration': 4.0},
#  {'text': 'us', 'start': 206.159, 'duration': 3.121},
#  {'text': 'that makes the field as much a field of',
#   'start': 207.12,
#   'duration': 4.08},
#  {'text': 'interest for computer scientists as it',
#   'start': 209.28,
#   'duration': 3.44},
#  {'text': 'is for psychologists', 'start': 211.2, 'duration': 4.48},
#  {'text': 'philosophers politicians and managers',
#   'start': 212.72,
#   'duration': 4.64},
#  {'text': 'there will be people to create it',
#   'start': 215.68,
#   'duration': 4.479},
#  {'text': 'others to observe it and ones to decide',
#   'start': 217.36,
#   'duration': 6.08},
#  {'text': 'how we will live with it', 'start': 220.159, 'duration': 3.281},
#  {'text': "number three cyber security we've",
#   'start': 223.68,
#   'duration': 4.479},
#  {'text': 'already talked about two industries that',
#   'start': 226.4,
#   'duration': 3.52},
#  {'text': 'will make our entire existence',
#   'start': 228.159,
#   'duration': 3.44},
#  {'text': 'more and more dependent on computer',
#   'start': 229.92,
#   'duration': 3.92},
#  {'text': "systems with that we'll come more",
#   'start': 231.599,
#   'duration': 4.241},
#  {'text': 'vulnerability to cyber attacks',
#   'start': 233.84,
#   'duration': 4.479},
#  {'text': 'hackers are already able to access bank',
#   'start': 235.84,
#   'duration': 3.039},
#  {'text': 'accounts', 'start': 238.319, 'duration': 2.56},
#  {'text': 'steal classified state information',
#   'start': 238.879,
#   'duration': 3.601},
#  {'text': 'freeze entire companies', 'start': 240.879, 'duration': 3.36},
#  {'text': 'completely and get their hands on our',
#   'start': 242.48,
#   'duration': 3.839},
#  {'text': 'personal information without proper',
#   'start': 244.239,
#   'duration': 3.841},
#  {'text': 'cyber security systems though', 'start': 246.319, 'duration': 3.92},
#  {'text': 'they will soon have potential access to',
#   'start': 248.08,
#   'duration': 4.159},
#  {'text': 'everything connected to the internet',
#   'start': 250.239,
#   'duration': 4.401},
#  {'text': 'which will be almost everything around',
#   'start': 252.239,
#   'duration': 5.041},
#  {'text': 'us from our houses to our cars to the',
#   'start': 254.64,
#   'duration': 4.879},
#  {'text': "medical equipment at hospitals that's",
#   'start': 257.28,
#   'duration': 4.0},
#  {'text': 'why the cyber security industry is our',
#   'start': 259.519,
#   'duration': 2.56},
#  {'text': 'only hope', 'start': 261.28, 'duration': 3.12},
#  {'text': 'for any real security in the future and',
#   'start': 262.079,
#   'duration': 3.521},
#  {'text': 'so it will grow', 'start': 264.4, 'duration': 3.28},
#  {'text': 'all the more important as more things in',
#   'start': 265.6,
#   'duration': 4.159},
#  {'text': 'our daily lives get connected', 'start': 267.68, 'duration': 3.84},
#  {'text': 'this industry is our main safeguard',
#   'start': 269.759,
#   'duration': 3.601},
#  {'text': "against humanity's future dreams",
#   'start': 271.52,
#   'duration': 5.2},
#  {'text': 'turning into real nightmares', 'start': 273.36, 'duration': 3.36},
#  {'text': 'number four genomics 15 years ago',
#   'start': 278.4,
#   'duration': 6.72},
#  {'text': 'exactly in 2003 the u.s founded', 'start': 282.08, 'duration': 5.2},
#  {'text': 'human genome project which had begun in',
#   'start': 285.12,
#   'duration': 3.359},
#  {'text': '1990', 'start': 287.28, 'duration': 3.44},
#  {'text': 'was finally capable of sequencing and',
#   'start': 288.479,
#   'duration': 4.241},
#  {'text': 'mapping the human genetic code', 'start': 290.72, 'duration': 4.96},
#  {'text': 'this project cost three billion dollars',
#   'start': 292.72,
#   'duration': 4.64},
#  {'text': 'if things had stayed at that cost',
#   'start': 295.68,
#   'duration': 3.6},
#  {'text': "the industry wouldn't carry much hope",
#   'start': 297.36,
#   'duration': 3.52},
#  {'text': 'since not many people would have been',
#   'start': 299.28,
#   'duration': 3.359},
#  {'text': 'willing to enter into something that',
#   'start': 300.88,
#   'duration': 2.56},
#  {'text': 'expensive', 'start': 302.639, 'duration': 3.28},
#  {'text': 'but today sequencing a genome can cost',
#   'start': 303.44,
#   'duration': 4.8},
#  {'text': 'just around a thousand dollars',
#   'start': 305.919,
#   'duration': 4.401},
#  {'text': 'today the field of genomics is at its',
#   'start': 308.24,
#   'duration': 4.239},
#  {'text': 'highest level of vigor with players like',
#   'start': 310.32,
#   'duration': 4.0},
#  {'text': 'bill gates and google jumping on its',
#   'start': 312.479,
#   'duration': 2.801},
#  {'text': 'bandwagon with', 'start': 314.32, 'duration': 3.04},
#  {'text': 'billions of dollars in investments with',
#   'start': 315.28,
#   'duration': 4.08},
#  {'text': 'the research being more facilitated',
#   'start': 317.36,
#   'duration': 3.92},
#  {'text': 'genomics is expanded to completely',
#   'start': 319.36,
#   'duration': 3.679},
#  {'text': 'transform our understanding of the human',
#   'start': 321.28,
#   'duration': 3.12},
#  {'text': "body's components", 'start': 323.039, 'duration': 4.72},
#  {'text': 'and our ability to cure and nurture it',
#   'start': 324.4,
#   'duration': 5.84},
#  {'text': 'our safeguard against cancer diabetes',
#   'start': 327.759,
#   'duration': 4.16},
#  {'text': 'and even our hope to quickly adapt our',
#   'start': 330.24,
#   'duration': 2.959},
#  {'text': 'bodies to the sky-high', 'start': 331.919, 'duration': 3.12},
#  {'text': 'rates of change in our environments in',
#   'start': 333.199,
#   'duration': 3.121},
#  {'text': 'the decades to come', 'start': 335.039, 'duration': 4.061},
#  {'text': 'all lie in genomics', 'start': 336.32, 'duration': 7.599},
#  {'text': '[Applause]', 'start': 339.1, 'duration': 6.58},
#  {'text': "that's an industry that is expected to",
#   'start': 343.919,
#   'duration': 3.921},
#  {'text': 'become worth more than 20 billion',
#   'start': 345.68,
#   'duration': 7.44},
#  {'text': "in 2022. that's only one year from now",
#   'start': 347.84,
#   'duration': 8.56},
#  {'text': 'number five drones drone technology is',
#   'start': 353.12,
#   'duration': 5.28},
#  {'text': 'now becoming more and more affordable in',
#   'start': 356.4,
#   'duration': 3.84},
#  {'text': 'the same way we just mentioned with',
#   'start': 358.4,
#   'duration': 2.88},
#  {'text': 'genomics', 'start': 360.24, 'duration': 2.959},
#  {'text': 'in the near past there were times when',
#   'start': 361.28,
#   'duration': 4.24},
#  {'text': 'drones were only novelty items that most',
#   'start': 363.199,
#   'duration': 4.641},
#  {'text': 'of us only associated with war and bomb',
#   'start': 365.52,
#   'duration': 2.799},
#  {'text': 'dropping', 'start': 367.84, 'duration': 3.12},
#  {'text': 'the missile was just a precaution today',
#   'start': 368.319,
#   'duration': 4.641},
#  {'text': 'drones are already becoming central to',
#   'start': 370.96,
#   'duration': 3.84},
#  {'text': 'everyday non-military tasks', 'start': 372.96, 'duration': 4.32},
#  {'text': 'like photography journalism and like',
#   'start': 374.8,
#   'duration': 4.64},
#  {'text': "amazon's use of them for delivery",
#   'start': 377.28,
#   'duration': 4.72},
#  {'text': 'the future is all for drones though and',
#   'start': 379.44,
#   'duration': 4.08},
#  {'text': 'they will become used in everything from',
#   'start': 382.0,
#   'duration': 3.52},
#  {'text': 'agriculture to delivering emergency aid',
#   'start': 383.52,
#   'duration': 3.44},
#  {'text': 'for victims of heart attacks', 'start': 385.52, 'duration': 2.799},
#  {'text': 'as they keep on gaining some', 'start': 386.96, 'duration': 3.2},
#  {'text': 'intelligence of their own as they',
#   'start': 388.319,
#   'duration': 2.961},
#  {'text': 'already are', 'start': 390.16, 'duration': 2.96},
#  {'text': "it won't be long before law enforcement",
#   'start': 391.28,
#   'duration': 4.0},
#  {'text': 'agencies start using them for patrol',
#   'start': 393.12,
#   'duration': 4.16},
#  {'text': 'and let these flying hawks identify the',
#   'start': 395.28,
#   'duration': 3.12},
#  {'text': 'bad guys', 'start': 397.28, 'duration': 2.88},
#  {'text': "there's literally no limit to the",
#   'start': 398.4,
#   'duration': 5.2},
#  {'text': 'potential drone applications', 'start': 400.16, 'duration': 3.44},
#  {'text': 'number six robotics for several years',
#   'start': 403.919,
#   'duration': 4.081},
#  {'text': 'now', 'start': 407.44, 'duration': 2.159},
#  {'text': 'more and more warehouses and', 'start': 408.0, 'duration': 3.44},
#  {'text': 'manufacturing plants have been including',
#   'start': 409.599,
#   'duration': 2.561},
#  {'text': 'robots', 'start': 411.44, 'duration': 3.12},
#  {'text': 'in their workforce now we have sophia',
#   'start': 412.16,
#   'duration': 4.319},
#  {'text': 'the saudi arabian humanoid that was the',
#   'start': 414.56,
#   'duration': 3.84},
#  {'text': 'first robot to acquire a national',
#   'start': 416.479,
#   'duration': 3.041},
#  {'text': 'citizenship', 'start': 418.4, 'duration': 2.639},
#  {'text': 'and there are robots that are', 'start': 419.52, 'duration': 3.28},
#  {'text': 'entertaining the seniors in retirement',
#   'start': 421.039,
#   'duration': 3.28},
#  {'text': 'homes in japan', 'start': 422.8, 'duration': 3.44},
#  {'text': "very soon we'll be having robots as our",
#   'start': 424.319,
#   'duration': 3.361},
#  {'text': 'friends co-workers and', 'start': 426.24, 'duration': 3.76},
#  {'text': 'in-house assistants blood on my mat',
#   'start': 427.68,
#   'duration': 3.6},
#  {'text': 'handle it', 'start': 430.0, 'duration': 2.72},
#  {'text': "that's why we now have robot", 'start': 431.28, 'duration': 3.44},
#  {'text': 'relationship researchers to decide',
#   'start': 432.72,
#   'duration': 3.759},
#  {'text': 'what set of rules will shape our',
#   'start': 434.72,
#   'duration': 3.599},
#  {'text': 'interactions with robots', 'start': 436.479, 'duration': 3.601},
#  {'text': 'some people might be afraid that robots',
#   'start': 438.319,
#   'duration': 3.841},
#  {'text': 'will one day take over our jobs',
#   'start': 440.08,
#   'duration': 3.92},
#  {'text': "but if you're a person working in the",
#   'start': 442.16,
#   'duration': 3.36},
#  {'text': 'vast field of robotics', 'start': 444.0, 'duration': 5.36},
#  {'text': "that's not a fear that you should share",
#   'start': 445.52,
#   'duration': 6.88},
#  {'text': 'number seven virtual reality being able',
#   'start': 449.36,
#   'duration': 5.04},
#  {'text': 'to simulate certain situations and',
#   'start': 452.4,
#   'duration': 4.0},
#  {'text': 'environments without the costs and risks',
#   'start': 454.4,
#   'duration': 4.239},
#  {'text': 'of the same experience in real life',
#   'start': 456.4,
#   'duration': 4.239},
#  {'text': 'opens up a gold mine of potential',
#   'start': 458.639,
#   'duration': 4.241},
#  {'text': 'applications that we could or could not',
#   'start': 460.639,
#   'duration': 3.601},
#  {'text': 'imagine at the moment', 'start': 462.88, 'duration': 4.4},
#  {'text': 'the technology of vr is already being',
#   'start': 464.24,
#   'duration': 3.76},
#  {'text': 'used by', 'start': 467.28, 'duration': 3.039},
#  {'text': 'military forces to train their soldiers',
#   'start': 468.0,
#   'duration': 4.08},
#  {'text': "people who are taking driver's license",
#   'start': 470.319,
#   'duration': 2.56},
#  {'text': 'tests', 'start': 472.08, 'duration': 3.6},
#  {'text': 'as well as in video games companies are',
#   'start': 472.879,
#   'duration': 4.961},
#  {'text': 'also using vr to train their employees',
#   'start': 475.68,
#   'duration': 3.359},
#  {'text': 'like exxon mobil', 'start': 477.84, 'duration': 3.28},
#  {'text': 'who use the technology to train its',
#   'start': 479.039,
#   'duration': 4.16},
#  {'text': 'engineers and field workers on fuel',
#   'start': 481.12,
#   'duration': 3.84},
#  {'text': 'production processes', 'start': 483.199, 'duration': 4.0},
#  {'text': "and that's only the tip of a massive",
#   'start': 484.96,
#   'duration': 3.84},
#  {'text': 'iceberg', 'start': 487.199, 'duration': 4.72},
#  {'text': 'number eight nanotechnology there are',
#   'start': 488.8,
#   'duration': 4.799},
#  {'text': 'countless ways in which we', 'start': 491.919, 'duration': 4.081},
#  {'text': 'as a species have our hopes hanging on',
#   'start': 493.599,
#   'duration': 4.04},
#  {'text': 'advancements in the fields of', 'start': 496.0, 'duration': 3.12},
#  {'text': 'nanotechnology', 'start': 497.639, 'duration': 3.56},
#  {'text': "today there's extensive research in the",
#   'start': 499.12,
#   'duration': 4.079},
#  {'text': 'field with the applications ranging from',
#   'start': 501.199,
#   'duration': 3.361},
#  {'text': 'medicine to agriculture', 'start': 503.199, 'duration': 2.881},
#  {'text': 'the possibilities are being studied',
#   'start': 504.56,
#   'duration': 3.6},
#  {'text': 'regarding how we can use nanotechnology',
#   'start': 506.08,
#   'duration': 4.0},
#  {'text': 'to speed up bone cell growth', 'start': 508.16, 'duration': 4.16},
#  {'text': 'the detection of cancer cells creating',
#   'start': 510.08,
#   'duration': 3.839},
#  {'text': 'self-cleaning surfaces', 'start': 512.32, 'duration': 3.44},
#  {'text': 'and implementing healthier and more',
#   'start': 513.919,
#   'duration': 3.92},
#  {'text': 'efficient irrigation methods', 'start': 515.76, 'duration': 3.759},
#  {'text': 'all of that potential says that the',
#   'start': 517.839,
#   'duration': 3.281},
#  {'text': 'future of nanotechnology', 'start': 519.519, 'duration': 4.161},
#  {'text': 'is only pointed in one direction endless',
#   'start': 521.12,
#   'duration': 4.8},
#  {'text': 'advancements', 'start': 523.68, 'duration': 4.56},
#  {'text': "where'd that come from it's nanotech you",
#   'start': 525.92,
#   'duration': 4.32},
#  {'text': 'like it', 'start': 528.24, 'duration': 5.2},
#  {'text': 'number nine renewable energy for several',
#   'start': 530.24,
#   'duration': 4.96},
#  {'text': 'years a growing number of people are',
#   'start': 533.44,
#   'duration': 2.56},
#  {'text': 'getting into an', 'start': 535.2, 'duration': 2.88},
#  {'text': 'ever inflating state of existential',
#   'start': 536.0,
#   'duration': 4.0},
#  {'text': 'panic because of the climate change that',
#   'start': 538.08,
#   'duration': 3.68},
#  {'text': 'is taking place as a result', 'start': 540.0, 'duration': 4.48},
#  {'text': 'of our two centuries long use of fossil',
#   'start': 541.76,
#   'duration': 3.28},
#  {'text': 'fuels', 'start': 544.48, 'duration': 3.039},
#  {'text': 'as our primary source of energy with',
#   'start': 545.04,
#   'duration': 4.08},
#  {'text': 'more people coming to realize the',
#   'start': 547.519,
#   'duration': 3.681},
#  {'text': 'magnitude of the global warming threat',
#   'start': 549.12,
#   'duration': 3.76},
#  {'text': 'governments companies and private',
#   'start': 551.2,
#   'duration': 3.44},
#  {'text': 'individuals are taking steps towards',
#   'start': 552.88,
#   'duration': 4.079},
#  {'text': 'depending on renewable sources of energy',
#   'start': 554.64,
#   'duration': 4.879},
#  {'text': 'like solar and wind the internet of',
#   'start': 556.959,
#   'duration': 3.361},
#  {'text': 'things boom', 'start': 559.519, 'duration': 2.561},
#  {'text': 'is set to further help these plans',
#   'start': 560.32,
#   'duration': 3.92},
#  {'text': 'materialize by facilitating private',
#   'start': 562.08,
#   'duration': 3.84},
#  {'text': 'power supply networks', 'start': 564.24, 'duration': 4.0},
#  {'text': 'according to some estimates renewable',
#   'start': 565.92,
#   'duration': 4.4},
#  {'text': 'energy is expected to fulfill almost',
#   'start': 568.24,
#   'duration': 4.159},
#  {'text': '100 of the power supply needed to run',
#   'start': 570.32,
#   'duration': 5.68},
#  {'text': "the world's economy by 2050.", 'start': 572.399, 'duration': 6.641},
#  {'text': "number 10 sharing economy we're moving",
#   'start': 576.0,
#   'duration': 3.92},
#  {'text': 'towards a world', 'start': 579.04, 'duration': 3.68},
#  {'text': 'where we will barely own stuff anymore',
#   'start': 579.92,
#   'duration': 4.4},
#  {'text': "we're coming to realize that", 'start': 582.72, 'duration': 4.4},
#  {'text': "it's often cheaper and more efficient to",
#   'start': 584.32,
#   'duration': 5.6},
#  {'text': 'rent whatever we can give up on owning',
#   'start': 587.12,
#   'duration': 4.159},
#  {'text': "uh we're here to serve you with a",
#   'start': 589.92,
#   'duration': 4.0},
#  {'text': 'court-ordered eviction okay', 'start': 591.279, 'duration': 4.24},
#  {'text': "we've been increasingly doing it with",
#   'start': 593.92,
#   'duration': 3.44},
#  {'text': 'car rides as more people are using',
#   'start': 595.519,
#   'duration': 3.361},
#  {'text': 'sharing services like uber', 'start': 597.36, 'duration': 3.28},
#  {'text': 'and the same with real estate renting',
#   'start': 598.88,
#   'duration': 3.68},
#  {'text': 'services like airbnb', 'start': 600.64, 'duration': 4.319},
#  {'text': 'today more services are joining that new',
#   'start': 602.56,
#   'duration': 4.56},
#  {'text': 'sharing model with apps being built on',
#   'start': 604.959,
#   'duration': 4.241},
#  {'text': 'rental services for household equipment',
#   'start': 607.12,
#   'duration': 4.8},
#  {'text': 'office spaces and even leisure boats',
#   'start': 609.2,
#   'duration': 3.92},
#  {'text': 'thanks to smartphones', 'start': 611.92, 'duration': 2.8},
#  {'text': 'more people are connected and thus',
#   'start': 613.12,
#   'duration': 3.6},
#  {'text': 'gaining access to these services on both',
#   'start': 614.72,
#   'duration': 5.359},
#  {'text': 'the provider and consumer sides',
#   'start': 616.72,
#   'duration': 6.48},
#  {'text': 'number 11 e-learning as we shift towards',
#   'start': 620.079,
#   'duration': 3.76},
#  {'text': 'a future', 'start': 623.2, 'duration': 2.48},
#  {'text': 'more dependent on innovation than on',
#   'start': 623.839,
#   'duration': 3.601},
#  {'text': 'formal college certificates', 'start': 625.68, 'duration': 3.599},
#  {'text': 'and where the value of your knowledge is',
#   'start': 627.44,
#   'duration': 3.44},
#  {'text': 'based on what you can create', 'start': 629.279, 'duration': 3.68},
#  {'text': 'and not what degrees you hold and',
#   'start': 630.88,
#   'duration': 3.76},
#  {'text': 'finally facilitated by all the',
#   'start': 632.959,
#   'duration': 3.601},
#  {'text': 'technologies we just mentioned', 'start': 634.64, 'duration': 3.92},
#  {'text': 'e-learning is definitely the future of',
#   'start': 636.56,
#   'duration': 3.04},
#  {'text': 'education', 'start': 638.56, 'duration': 2.64},
#  {'text': 'with more people on the internet than',
#   'start': 639.6,
#   'duration': 3.84},
#  {'text': 'ever before and with vr technology and',
#   'start': 641.2,
#   'duration': 3.84},
#  {'text': 'artificial intelligence applications',
#   'start': 643.44,
#   'duration': 3.76},
#  {'text': 'expanding into our daily lives', 'start': 645.04, 'duration': 4.4},
#  {'text': 'creating more engaging customizable and',
#   'start': 647.2,
#   'duration': 3.92},
#  {'text': 'effective learning experiences', 'start': 649.44, 'duration': 3.68},
#  {'text': 'will make e-learning the primary means',
#   'start': 651.12,
#   'duration': 3.839},
#  {'text': 'of education in the not very far',
#   'start': 653.12,
#   'duration': 5.68},
#  {'text': 'future number 12', 'start': 654.959, 'duration': 6.801},
#  {'text': 'big data you probably noticed that',
#   'start': 658.8,
#   'duration': 4.64},
#  {'text': 'almost every industry we mentioned',
#   'start': 661.76,
#   'duration': 4.24},
#  {'text': 'is dependent on data in one way or',
#   'start': 663.44,
#   'duration': 3.44},
#  {'text': 'another', 'start': 666.0, 'duration': 3.04},
#  {'text': 'data is what artificial intelligence',
#   'start': 666.88,
#   'duration': 3.519},
#  {'text': 'systems learn from', 'start': 669.04, 'duration': 3.12},
#  {'text': 'and increasing the efficiency of our',
#   'start': 670.399,
#   'duration': 3.12},
#  {'text': 'economic decisions', 'start': 672.16, 'duration': 3.84},
#  {'text': 'will be in the first place a matter of',
#   'start': 673.519,
#   'duration': 3.601},
#  {'text': 'good data', 'start': 676.0, 'duration': 3.519},
#  {'text': 'whoever is able to acquire data and has',
#   'start': 677.12,
#   'duration': 4.32},
#  {'text': 'the proper methods for analyzing it',
#   'start': 679.519,
#   'duration': 3.521},
#  {'text': 'will be a central player in the future',
#   'start': 681.44,
#   'duration': 4.079},
#  {'text': 'economy data scientists are right now',
#   'start': 683.04,
#   'duration': 4.16},
#  {'text': 'becoming essential players in', 'start': 685.519, 'duration': 4.0},
#  {'text': 'every arena from marketing to healthcare',
#   'start': 687.2,
#   'duration': 4.8},
#  {'text': 'to politics', 'start': 689.519, 'duration': 5.76},
#  {'text': 'number 13 3d printing 3d printing',
#   'start': 692.0,
#   'duration': 5.12},
#  {'text': 'technologies now include all kinds of',
#   'start': 695.279,
#   'duration': 2.481},
#  {'text': 'material', 'start': 697.12, 'duration': 2.719},
#  {'text': 'enabling individuals to home manufacture',
#   'start': 697.76,
#   'duration': 4.0},
#  {'text': 'their own spare parts and stationary',
#   'start': 699.839,
#   'duration': 2.481},
#  {'text': 'items', 'start': 701.76, 'duration': 2.56},
#  {'text': 'and at the same time giving companies',
#   'start': 702.32,
#   'duration': 3.68},
#  {'text': 'new alternatives for construction and',
#   'start': 704.32,
#   'duration': 3.28},
#  {'text': 'car manufacturing', 'start': 706.0, 'duration': 3.44},
#  {'text': 'this technology is giving us bright',
#   'start': 707.6,
#   'duration': 4.08},
#  {'text': 'visions of a future where manufacturing',
#   'start': 709.44,
#   'duration': 4.56},
#  {'text': 'is democratized will it be the end of',
#   'start': 711.68,
#   'duration': 3.839},
#  {'text': 'mass production', 'start': 714.0, 'duration': 3.76},
#  {'text': "possibly but that's a bit far-fetched",
#   'start': 715.519,
#   'duration': 4.32},
#  {'text': 'and extra optimistic', 'start': 717.76, 'duration': 4.56},
#  {'text': 'what we know is that 3d printing will',
#   'start': 719.839,
#   'duration': 4.56},
#  {'text': 'transform our manufacturing capabilities',
#   'start': 722.32,
#   'duration': 3.04},
#  {'text': 'and costs', 'start': 724.399, 'duration': 3.281},
#  {'text': 'and will make us as individuals able to',
#   'start': 725.36,
#   'duration': 4.4},
#  {'text': 'create our own products in our very own',
#   'start': 727.68,
#   'duration': 3.04},
#  {'text': 'homes', 'start': 729.76, 'duration': 3.04},
#  {'text': 'it will also cut a large portion of',
#   'start': 730.72,
#   'duration': 4.08},
#  {'text': 'companies construction and manufacturing',
#   'start': 732.8,
#   'duration': 3.039},
#  {'text': 'costs', 'start': 734.8, 'duration': 2.88},
#  {'text': 'all we can be sure of is that 3d',
#   'start': 735.839,
#   'duration': 3.12},
#  {'text': 'printing is the tool', 'start': 737.68, 'duration': 5.36},
#  {'text': 'of our new industrial era', 'start': 738.959, 'duration': 4.081},
#  {'text': 'number 14 blockchain technology with the',
#   'start': 743.6,
#   'duration': 4.88},
#  {'text': 'bitcoin frenzy that has taken over the',
#   'start': 746.8,
#   'duration': 3.2},
#  {'text': "world's financial markets in the past",
#   'start': 748.48,
#   'duration': 2.32},
#  {'text': 'couple of years', 'start': 750.0, 'duration': 2.88},
#  {'text': 'we came to frequently hear the term',
#   'start': 750.8,
#   'duration': 3.2},
#  {'text': 'blockchain', 'start': 752.88, 'duration': 3.04},
#  {'text': "it's the decentralized public ledger",
#   'start': 754.0,
#   'duration': 2.88},
#  {'text': 'mechanism at the heart of', 'start': 755.92, 'duration': 2.159},
#  {'text': 'cryptocurrencies but', 'start': 756.88, 'duration': 3.36},
#  {'text': 'cryptocurrencies are far from its only',
#   'start': 758.079,
#   'duration': 3.2},
#  {'text': 'application', 'start': 760.24, 'duration': 2.64},
#  {'text': 'if there is one technology that has the',
#   'start': 761.279,
#   'duration': 4.0},
#  {'text': 'potential to create the decentralized',
#   'start': 762.88,
#   'duration': 4.399},
#  {'text': 'comprehensive ecosystem that will',
#   'start': 765.279,
#   'duration': 4.161},
#  {'text': 'facilitate all of these other industries',
#   'start': 767.279,
#   'duration': 4.081},
#  {'text': 'we mentioned in a more secure and',
#   'start': 769.44,
#   'duration': 2.959},
#  {'text': 'efficient way', 'start': 771.36, 'duration': 3.68},
#  {'text': 'it is definitely blockchain based on',
#   'start': 772.399,
#   'duration': 3.601},
#  {'text': 'this technology', 'start': 775.04, 'duration': 2.479},
#  {'text': 'there are companies being launched that',
#   'start': 776.0,
#   'duration': 3.76},
#  {'text': 'want to put our finances research',
#   'start': 777.519,
#   'duration': 4.081},
#  {'text': 'identity management and even voting',
#   'start': 779.76,
#   'duration': 3.92},
#  {'text': 'processes on the blockchain', 'start': 781.6, 'duration': 3.84},
#  {'text': "it's basically the new face of the",
#   'start': 783.68,
#   'duration': 3.599},
#  {'text': 'internet and innovations in this',
#   'start': 785.44,
#   'duration': 3.519},
#  {'text': 'technology will become among the most',
#   'start': 787.279,
#   'duration': 3.68},
#  {'text': 'valuable contributions anyone can make',
#   'start': 788.959,
#   'duration': 5.041},
#  {'text': 'to the future economy', 'start': 790.959, 'duration': 3.041},
#  {'text': 'let us know in the comments what other',
#   'start': 794.32,
#   'duration': 3.68},
#  {'text': 'industries do you think will come to',
#   'start': 796.079,
#   'duration': 3.601},
#  {'text': 'define the upcoming era', 'start': 798.0, 'duration': 3.68},
#  {'text': "and don't forget to subscribe to our",
#   'start': 799.68,
#   'duration': 3.52},
#  {'text': 'channel and hit the ring bell', 'start': 801.68, 'duration': 2.959},
#  {'text': 'notifications button', 'start': 803.2, 'duration': 12.639},
#  {'text': 'to know whenever we post any new videos',
#   'start': 804.639,
#   'duration': 11.2},
#  {'text': 'you', 'start': 817.68, 'duration': 2.08}]

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'text': '[Applause]', 'start': 9.76, 'duration': 5.999},
#  {'text': '14 growing industries of the future',
#   'start': 12.799,
#   'duration': 4.801},
#  {'text': 'in the past few years the leaps being',
#   'start': 15.759,
#   'duration': 4.001},
#  {'text': 'made in our entire global economic',
#   'start': 17.6,
#   'duration': 2.72},
#  {'text': 'system', 'start': 19.76, 'duration': 3.519}]

# %%
Text = " "
for i in transcript:
  Text += ' ' + i['text']
print(Text)
# Out:
#   [Applause] 14 growing industries of the future in the past few years the leaps being made in our entire global economic system are quicker and larger than ever not many economists or tech experts can answer with confidence how they envision the economy 20 years from today as new technologies are prevailing new horizons are being tapped and new industries are being shaped that we never thought of until recently being able to forecast these changes will be the most critical factor in your decision to pursue a certain career or invest in one industry or the other that's why we thought we should imagine together which way the ship is sailing so here are 14 growing industries of the future number one internet of things in the past the internet was the thing that most of us used only when we were on our computers then some years ago it began making it to our mobile phones then our video game consoles and today we're heading in a path where we won't need to say i'm on the internet any longer i did not see that coming almost everything we use both indoors and outdoors will be on the internet from our fridges and washing machines to our power supply and home security systems that's why knowledge of networks data communication and software will be skills that are needed in pretty much every single industry out there manufacturing construction and service industries will be on a constant search for new internet-based mechanisms to incorporate into their product in order to gain an edge in the market the tech geeks will become the ones helping operate our entire environment the internet of things will actually include almost all of the things internet so helpful number two artificial intelligence google studies our behavior facebook learns our preferences we ask siri to find us near places to eat and we let amazon guide us through the vast aisles of the digital market ever since the machines began acquiring knowledge of their own they have taken huge leaps towards developing a real humanly consciousness today we're on the verge of an era where we will move around in self-driving cars work alongside robots and read books or listen to music that was created by a machine some of us are actually doing some of these things already alexa can you pour me a cup of water watch watch watch what the field of artificial intelligence in the coming decades will become one of the most vibrant arenas for endless experimentation also as everything becomes connected thanks to the internet of things more and more data related our behavior will be collected and the machines will have infinitely more material to learn from don't forget that artificial intelligence is not only a field that is exclusive to the computer scientists we're talking about creating brains like ours and potentially ones that will even be way more powerful than ours they will live with talk to and affect us that makes the field as much a field of interest for computer scientists as it is for psychologists philosophers politicians and managers there will be people to create it others to observe it and ones to decide how we will live with it number three cyber security we've already talked about two industries that will make our entire existence more and more dependent on computer systems with that we'll come more vulnerability to cyber attacks hackers are already able to access bank accounts steal classified state information freeze entire companies completely and get their hands on our personal information without proper cyber security systems though they will soon have potential access to everything connected to the internet which will be almost everything around us from our houses to our cars to the medical equipment at hospitals that's why the cyber security industry is our only hope for any real security in the future and so it will grow all the more important as more things in our daily lives get connected this industry is our main safeguard against humanity's future dreams turni ...

# %%
len(str(Text))
# Out:
# 12451

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to t5-small (https://huggingface.co/t5-small)
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
num_iters = int(len(Text)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + Text[start:end])
  out = summarizer(Text[start:end])
  out = out[0] 
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

#print(summarized_text)
# Out:
# input text
#   [Applause] 14 growing industries of the future in the past few years the leaps being made in our entire global economic system are quicker and larger than ever not many economists or tech experts can answer with confidence how they envision the economy 20 years from today as new technologies are prevailing new horizons are being tapped and new industries are being shaped that we never thought of until recently being able to forecast these changes will be the most critical factor in your decision to pursue a certain career or invest in one industry or the other that's why we thought we should imagine together which way the ship is sailing so here are 14 growing industries of the future number one internet of things in the past the internet was the thing that most of us used only when we were on our computers then some years ago it began making it to our mobile phones then our video game consoles and today we're heading in a path where we won't need to say i'm on the internet any longe
# Your max_length is set to 200, but you input_length is only 186. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
# Summarized text
# 14 growing industries of the future in the past few years are faster and larger than ever . we never thought of these changes until recently being able to forecast these changes will be the most critical factor in your decision to pursue a certain career or invest in one industry or the other . today we're heading in a path where we won't need to say i'm on the internet any longee .
# input text
# r i did not see that coming almost everything we use both indoors and outdoors will be on the internet from our fridges and washing machines to our power supply and home security systems that's why knowledge of networks data communication and software will be skills that are needed in pretty much every single industry out there manufacturing construction and service industries will be on a constant search for new internet-based mechanisms to incorporate into their product in order to gain an edge in the market the tech geeks will become the ones helping operate our entire environment the internet of things will actually include almost all of the things internet so helpful number two artificial intelligence google studies our behavior facebook learns our preferences we ask siri to find us near places to eat and we let amazon guide us through the vast aisles of the digital market ever since the machines began acquiring knowledge of their own they have taken huge leaps towards developing
# Summarized text
# tech geeks will become the ones helping operate our entire environment the internet of things will actually include almost all of the things internet so helpful number two artificial intelligence google studies our behavior facebook learns our preferences we ask siri to find us near places to eat and we let amazon guide us through the vast aisles of the digital market ever since the machines began acquiring knowledge of their own .
# input text
# a real humanly consciousness today we're on the verge of an era where we will move around in self-driving cars work alongside robots and read books or listen to music that was created by a machine some of us are actually doing some of these things already alexa can you pour me a cup of water watch watch watch what the field of artificial intelligence in the coming decades will become one of the most vibrant arenas for endless experimentation also as everything becomes connected thanks to the internet of things more and more data related our behavior will be collected and the machines will have infinitely more material to learn from don't forget that artificial intelligence is not only a field that is exclusive to the computer scientists we're talking about creating brains like ours and potentially ones that will even be way more powerful than ours they will live with talk to and affect us that makes the field as much a field of interest for computer scientists as it is for psychologist
# Your max_length is set to 200, but you input_length is only 180. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=90)
# Summarized text
# we're on the verge of an era where we will move around in self-driving cars work alongside robots and read books or listen to music that was created by a machine some of us are actually doing some of these things already alexa can you pour me a cup of water watch watch watch what the field of artificial intelligence in the coming decades will become one of the most vibrant arenas for endless experimentation .
# input text
# s philosophers politicians and managers there will be people to create it others to observe it and ones to decide how we will live with it number three cyber security we've already talked about two industries that will make our entire existence more and more dependent on computer systems with that we'll come more vulnerability to cyber attacks hackers are already able to access bank accounts steal classified state information freeze entire companies completely and get their hands on our personal information without proper cyber security systems though they will soon have potential access to everything connected to the internet which will be almost everything around us from our houses to our cars to the medical equipment at hospitals that's why the cyber security industry is our only hope for any real security in the future and so it will grow all the more important as more things in our daily lives get connected this industry is our main safeguard against humanity's future dreams turni
# Summarized text
# the cyber security industry is our only hope for any real security in the future . we'll come more vulnerability to cyber attacks hackers are already able to access bank accounts steal classified state information freeze entire companies completely and get their hands on our personal information without proper cyber security systems . this is our main safeguard against humanity's future dreams turni .
# input text
# ng into real nightmares number four genomics 15 years ago exactly in 2003 the u.s founded human genome project which had begun in 1990 was finally capable of sequencing and mapping the human genetic code this project cost three billion dollars if things had stayed at that cost the industry wouldn't carry much hope since not many people would have been willing to enter into something that expensive but today sequencing a genome can cost just around a thousand dollars today the field of genomics is at its highest level of vigor with players like bill gates and google jumping on its bandwagon with billions of dollars in investments with the research being more facilitated genomics is expanded to completely transform our understanding of the human body's components and our ability to cure and nurture it our safeguard against cancer diabetes and even our hope to quickly adapt our bodies to the sky-high rates of change in our environments in the decades to come all lie in genomics [Applause]
# Summarized text
# in 2003 the u.s founded human genome project was finally capable of sequencing and mapping the human genetic code this project cost three billion dollars . today sequencing a genome can cost just around a thousand dollars today the field of genomics is at its highest level of vigor . players like bill gates and google jump on its bandwagon with billions of dollars in investments .
# input text
#  that's an industry that is expected to become worth more than 20 billion in 2022. that's only one year from now number five drones drone technology is now becoming more and more affordable in the same way we just mentioned with genomics in the near past there were times when drones were only novelty items that most of us only associated with war and bomb dropping the missile was just a precaution today drones are already becoming central to everyday non-military tasks like photography journalism and like amazon's use of them for delivery the future is all for drones though and they will become used in everything from agriculture to delivering emergency aid for victims of heart attacks as they keep on gaining some intelligence of their own as they already are it won't be long before law enforcement agencies start using them for patrol and let these flying hawks identify the bad guys there's literally no limit to the potential drone applications number six robotics for several years now
# Summarized text
# number five drones drone technology is expected to become worth more than 20 billion in 2022 . drones are already becoming central to everyday non-military tasks like photography journalism and like amazon's use of them for delivery the future is all for drones . they will become used in everything from agriculture to delivering emergency aid for victims of heart attacks as they keep on on some intelligence of their own .
# input text
#  more and more warehouses and manufacturing plants have been including robots in their workforce now we have sophia the saudi arabian humanoid that was the first robot to acquire a national citizenship and there are robots that are entertaining the seniors in retirement homes in japan very soon we'll be having robots as our friends co-workers and in-house assistants blood on my mat handle it that's why we now have robot relationship researchers to decide what set of rules will shape our interactions with robots some people might be afraid that robots will one day take over our jobs but if you're a person working in the vast field of robotics that's not a fear that you should share number seven virtual reality being able to simulate certain situations and environments without the costs and risks of the same experience in real life opens up a gold mine of potential applications that we could or could not imagine at the moment the technology of vr is already being used by military forces
# Your max_length is set to 200, but you input_length is only 193. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=96)
# Summarized text
# sophia the saudi arabian humanoid was the first robot to acquire a national citizenship . there are robots that are entertaining the seniors in retirement homes in japan . we now have robot relationship researchers to decide what set of rules will shape our interactions with robots some people might be afraid that robots will one day take over our jobs .
# input text
# to train their soldiers people who are taking driver's license tests as well as in video games companies are also using vr to train their employees like exxon mobil who use the technology to train its engineers and field workers on fuel production processes and that's only the tip of a massive iceberg number eight nanotechnology there are countless ways in which we as a species have our hopes hanging on advancements in the fields of nanotechnology today there's extensive research in the field with the applications ranging from medicine to agriculture the possibilities are being studied regarding how we can use nanotechnology to speed up bone cell growth the detection of cancer cells creating self-cleaning surfaces and implementing healthier and more efficient irrigation methods all of that potential says that the future of nanotechnology is only pointed in one direction endless advancements where'd that come from it's nanotech you like it number nine renewable energy for several years
# Summarized text
# the future of nanotechnology is only pointed in one direction endless advancements where'd that come from it's nanotech you like it number nine renewable energy for several years . there's extensive research in the field with the applications ranging from medicine to agriculture . the possibilities are being studied regarding how we can use nanotechnology to speed up bone cell growth the detection of cancer cells creating self-cleaning surfaces .
# input text
# a growing number of people are getting into an ever inflating state of existential panic because of the climate change that is taking place as a result of our two centuries long use of fossil fuels as our primary source of energy with more people coming to realize the magnitude of the global warming threat governments companies and private individuals are taking steps towards depending on renewable sources of energy like solar and wind the internet of things boom is set to further help these plans materialize by facilitating private power supply networks according to some estimates renewable energy is expected to fulfill almost 100 of the power supply needed to run the world's economy by 2050. number 10 sharing economy we're moving towards a world where we will barely own stuff anymore we're coming to realize that it's often cheaper and more efficient to rent whatever we can give up on owning uh we're here to serve you with a court-ordered eviction okay we've been increasingly doing it
# Your max_length is set to 200, but you input_length is only 183. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=91)
# Summarized text
# the internet of things boom is set to further help these plans materialize by facilitating private power supply networks according to some estimates renewable energy is expected to fulfill almost 100 of the power supply needed to run the world's economy by 2050 . government companies and private individuals are taking steps towards depending on renewable sources of energy like solar and wind .
# input text
#  with car rides as more people are using sharing services like uber and the same with real estate renting services like airbnb today more services are joining that new sharing model with apps being built on rental services for household equipment office spaces and even leisure boats thanks to smartphones more people are connected and thus gaining access to these services on both the provider and consumer sides number 11 e-learning as we shift towards a future more dependent on innovation than on formal college certificates and where the value of your knowledge is based on what you can create and not what degrees you hold and finally facilitated by all the technologies we just mentioned e-learning is definitely the future of education with more people on the internet than ever before and with vr technology and artificial intelligence applications expanding into our daily lives creating more engaging customizable and effective learning experiences will make e-learning the primary means o
# Your max_length is set to 200, but you input_length is only 190. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Summarized text
# e-learning is definitely the future of education with more people on the internet than ever before . with vr technology and artificial intelligence applications expanding into our daily lives creating more engaging customizable and effective learning experiences will make elearning the primary means .
# input text
# f education in the not very far future number 12 big data you probably noticed that almost every industry we mentioned is dependent on data in one way or another data is what artificial intelligence systems learn from and increasing the efficiency of our economic decisions will be in the first place a matter of good data whoever is able to acquire data and has the proper methods for analyzing it will be a central player in the future economy data scientists are right now becoming essential players in every arena from marketing to healthcare to politics number 13 3d printing 3d printing technologies now include all kinds of material enabling individuals to home manufacture their own spare parts and stationary items and at the same time giving companies new alternatives for construction and car manufacturing this technology is giving us bright visions of a future where manufacturing is democratized will it be the end of mass production possibly but that's a bit far-fetched and extra opti
# Your max_length is set to 200, but you input_length is only 190. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
# Summarized text
# f education in the not very far future number 12 big data you probably noticed that almost every industry is dependent on data in one way or another data is what artificial intelligence systems learn from . whoever is able to acquire data and has the proper methods for analyzing it will be a central player in the future economy data scientists are right now becoming essential players in every arena from marketing to healthcare to politics number 13 3d printing technologies now include all kinds of material enabling individuals to home manufacture their own spare parts and stationary items .
# input text
# mistic what we know is that 3d printing will transform our manufacturing capabilities and costs and will make us as individuals able to create our own products in our very own homes it will also cut a large portion of companies construction and manufacturing costs all we can be sure of is that 3d printing is the tool of our new industrial era number 14 blockchain technology with the bitcoin frenzy that has taken over the world's financial markets in the past couple of years we came to frequently hear the term blockchain it's the decentralized public ledger mechanism at the heart of cryptocurrencies but cryptocurrencies are far from its only application if there is one technology that has the potential to create the decentralized comprehensive ecosystem that will facilitate all of these other industries we mentioned in a more secure and efficient way it is definitely blockchain based on this technology there are companies being launched that want to put our finances research identity ma
# Your max_length is set to 200, but you input_length is only 90. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Summarized text
# 3d printing is the tool of our new industrial era number 14 blockchain technology with the bitcoin frenzy that has taken over the world's financial markets in the past couple of years . cryptocurrencies are far from its only application if there is one technology that has the potential to create the decentralized comprehensive ecosystem that will facilitate all of these other industries we mentioned in a more secure and efficient way .
# input text
# nagement and even voting processes on the blockchain it's basically the new face of the internet and innovations in this technology will become among the most valuable contributions anyone can make to the future economy let us know in the comments what other industries do you think will come to define the upcoming era and don't forget to subscribe to our channel and hit the ring bell notifications button to know whenever we post any new videos you
# Summarized text
# nagement and even voting processes on the blockchain it's basically the new face of the internet and innovations in this technology will become among the most valuable contributions anyone can make . don't forget to subscribe to our channel and hit the ring bell notifications button to know whenever we post any new videos .

# %%
len(str(summarized_text))
# Out:
# 5361

# %%
str(summarized_text)
# Out:
# '["14 growing industries of the future in the past few years are faster and larger than ever . we never thought of these changes until recently being able to forecast these changes will be the most critical factor in your decision to pursue a certain career or invest in one industry or the other . today we\'re heading in a path where we won\'t need to say i\'m on the internet any longee .", \'tech geeks will become the ones helping operate our entire environment the internet of things will actually include almost all of the things internet so helpful number two artificial intelligence google studies our behavior facebook learns our preferences we ask siri to find us near places to eat and we let amazon guide us through the vast aisles of the digital market ever since the machines began acquiring knowledge of their own .\', "we\'re on the verge of an era where we will move around in self-driving cars work alongside robots and read books or listen to music that was created by a machine some of us are actually doing some of these things already alexa can you pour me a cup of water watch watch watch what the field of artificial intelligence in the coming decades will become one of the most vibrant arenas for endless experimentation .", "the cyber security industry is our only hope for any real security in the future . we\'ll come more vulnerability to cyber attacks hackers are already able to access bank accounts steal classified state information freeze entire companies completely and get their hands on our personal information without proper cyber security systems . this is our main safeguard against humanity\'s future dreams turni .", \'in 2003 the u.s founded human genome project was finally capable of sequencing and mapping the human genetic code this project cost three billion dollars . today sequencing a genome can cost just around a thousand dollars today the field of genomics is at its highest level of vigor . players like bill gates and google jump on its bandwagon with billions of dollars in investments .\', "number five drones drone technology is expected to become worth more than 20 billion in 2022 . drones are already becoming central to everyday non-military tasks like photography journalism and like amazon\'s use of them for delivery the future is all for drones . they will become used in everything from agriculture to delivering emergency aid for victims of heart attacks as they keep on on some intelligence of their own .", \'sophia the saudi arabian humanoid was the first robot to acquire a national citizenship . there are robots that are entertaining the seniors in retirement homes in japan . we now have robot relationship researchers to decide what set of rules will shape our interactions with robots some people might be afraid that robots will one day take over our jobs .\', "the future of nanotechnology is only pointed in one direction endless advancements where\'d that come from it\'s nanotech you like it number nine renewable energy for several years . there\'s extensive research in the field with the applications ranging from medicine to agriculture . the possibilities are being studied regarding how we can use nanotechnology to speed up bone cell growth the detection of cancer cells creating self-cleaning surfaces .", "the internet of things boom is set to further help these plans materialize by facilitating private power supply networks according to some estimates renewable energy is expected to fulfill almost 100 of the power supply needed to run the world\'s economy by 2050 . government companies and private individuals are taking steps towards depending on renewable sources of energy like solar and wind .", \'e-learning is definitely the future of education with more people on the internet than ever before . with vr technology and artificial intelligence applications expanding into our daily lives creating more engaging customizable and effective learning experiences will make elearning the primary me ...
